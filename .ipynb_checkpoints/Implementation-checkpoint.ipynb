# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt
from pylab import rcParams

# %%
rcParams['figure.figsize'] = 14,28

# %%
from ImageHandler import *
from ImageProcessing import *
from Processing import *

# %%
image = loadImage('Test-data/050200074.jpg');
(h, w) = np.shape(image);
_, image = cv.threshold(image,0,255,cv.THRESH_BINARY+cv.THRESH_OTSU)
plt.imshow(image);

# %%
width = int (0.05 * w);
(h, w) = np.shape(image);
strips = (int (w/width) + (1 if w%width != 0 else 0));
M = 1;

wt = getWeights(M);
pp = [];
for i in range(strips):
    pp.append(projectionProfile(image, width, i));

delta = getdelta(image, width, strips, pp);
SPR = [];
for i in range(strips):
    SPR.append(getSPR(image, M, i, delta, wt, pp, strips));
    
dSPR = [];
CCheight = getCCHeight(image);
for i in range(strips):
    dSPR.append(getdiffSPR(SPR[i], image, CCheight));

# %%
showLine(image, dSPR, strips, width);

# %%
nRegions = applyViterbi(dSPR, strips, pp, width, CCheight, w)
showRegions(image, nRegions);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-1fc83240b7cf> in <module>
# ----> 1 nRegions = applyViterbi(dSPR, strips, pp, width, CCheight)
#       2 showRegions(image, nRegions);
#
# ~/Documents/Projects/Jupyter/Text Segmentation/Papvassiliou/Processing.py in applyViterbi(dSPR, strips, pp, width, CCheight)
#      10     regions, m0, m1 = getRegions(dSPR, CCheight);
#      11     probabilities = [];
# ---> 12     e0, e1 = getEmission(pp, regions, width, CCheight);
#      13     nRegions = [];
#      14     for i in range(len(regions)):
#
# ~/Documents/Projects/Jupyter/Text Segmentation/Papvassiliou/Processing.py in getEmission(pp, regions, width, CCheight)
#      44             if region[1] < (CCheight / 5):
#      45                 continue;
# ---> 46             total = (width if (i+1)*width <= w else (w - i*width));
#      47             value = np.sum(pp[i][region[0]:region[0] + region[1]]);
#      48             if (value == 0):
#
# NameError: name 'w' is not defined
